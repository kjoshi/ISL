# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sb

# %% [markdown]
# 9) This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.
#
# (a) Which of the predictors are quantitative, and which are qualitative?

# %%
auto = pd.read_csv("Auto.csv", na_values=['?'])
print(auto.shape)
auto = auto.dropna()
print(auto.shape)
auto[0:5]
# Out:
# (397, 9)
# (392, 9)
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# Quantitative variables:
# mpg, displacement, horsepower, weight, acceleration
#
# Qualitative variables:
# cylinders, year, origin, name

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can answer
# this using the range() function.
#
# (c) What is the mean and standard deviation of each quantitative predictor?
#
# We can find both of these using the pandas describe() function:

# %%
auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
auto_stripped = auto.drop(auto.index[range(10,85)])
auto_stripped.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  317.000000  317.000000    317.000000  317.000000   317.000000
# mean    24.374763    5.381703    187.880126  101.003155  2938.854890
# std      7.872565    1.658135    100.169973   36.003208   811.640668
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    101.000000   75.000000  2215.000000
# 50%     23.900000    4.000000    146.000000   90.000000  2795.000000
# 75%     30.500000    6.000000    250.000000  115.000000  3520.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    317.000000  317.000000  317.000000
# mean      15.704101   77.123028    1.599369
# std        2.719913    3.127158    0.819308
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically,
# using scatterplots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment
# on your findings.

# %%
sb.pairplot(auto)

# %% [markdown]
# Positive correlations between:
# horsepower & weight, displacement & weight, displacement & horsepower.
#
# - Heavier cars typically have larger, heavier engines with more horsepower.
#
# Weaker positive correletion between cylinders and horsepower/weight/displacement.
#
# Negative correlation between mpg and horsepower, weight, displacement
#
#  - Heavier more powerful cars run less efficiently.
#
# Weak negative correlation between acceleration and horsepower.
#
#  - Cars with higher horsepower accelerate more slowly.
#
# No correlation between acceleration and weight.
#
#  - Heavier cars don't accelerate more slowly than lighter ones.
#
# Weak positive correlation between year & mpg.
#
#  - Newer cars are more fuel efficient.
#
# No strong correlations between origin and anything else.
